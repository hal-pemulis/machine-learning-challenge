# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in /opt/anaconda3/lib/python3.7/site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in /opt/anaconda3/lib/python3.7/site-packages (from sklearn) (0.23.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /opt/anaconda3/lib/python3.7/site-packages (from scikit-learn->sklearn) (0.13.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /opt/anaconda3/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.17.2)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /opt/anaconda3/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from scikit-learn->sklearn) (2.1.0)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.7/site-packages (0.13.2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning¶

# %%
df = pd.read_csv("../Resources/exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df[['koi_period', 'koi_time0bk', 'koi_impact', 'koi_duration', 'koi_depth', 
                        'koi_prad', 'koi_teq', 'koi_insol', 'koi_tce_plnt_num',
                        'koi_model_snr', 'koi_steff', 'koi_slogg', 'koi_srad', ]]

print(selected_features.shape)
# Out:
# (6991, 13)

# %%
target = df["koi_disposition"]
target_names = ["CANDIDATE", "CONFIRMED", "FALSE POSITIVE"]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale data
from sklearn.preprocessing import MinMaxScaler

# define min max scaler
scaler = MinMaxScaler(feature_range=(0, 2))
# transform data
X_scaled = scaler.fit_transform(selected_features)

pd.DataFrame(X_scaled).head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.101139  0.062127  0.011626  0.062729  0.001125  0.000027  0.048165
# 1  0.036676  0.081855  0.019225  0.023346  0.014041  0.000144  0.074923
# 2  0.002758  0.073656  0.025316  0.032368  0.010473  0.000333  0.178799
# 3  0.004231  0.075561  0.013908  0.021500  0.000773  0.000026  0.180309
# 4  0.007236  0.077608  0.015118  0.042974  0.000880  0.000026  0.146552
#
#           7         8         9        10        11        12
# 0  0.000002  0.285714  0.005346  0.422214  1.662592  0.009094
# 1  0.000007  0.000000  0.016503  0.482357  1.691555  0.008438
# 2  0.000163  0.000000  0.111343  0.475104  1.699078  0.007582
# 3  0.000169  0.000000  0.008682  0.509256  1.651683  0.010417
# 4  0.000078  0.285714  0.008527  0.511522  1.669739  0.009594

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, target, random_state=42)

# %% [markdown]
# # Test 1: KNN
# Just making sure this works

# %%
from sklearn.neighbors import KNeighborsClassifier
# Loop through different k values to see which has the highest accuracy
# Note: We only use odd numbers because we don't want any ties
train_scores = []
test_scores = []
for k in range(1, 20, 2):
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(X_train, y_train)
    train_score = model.score(X_train, y_train)
    test_score = model.score(X_test, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    
plt.plot(range(1, 20, 2), train_scores, marker='o')
plt.plot(range(1, 20, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()

# %%
# Choose the best k from above and re-fit the KNN Classifier using that k value.
# print the score for the test data
# YOUR CODE HERE

knn = KNeighborsClassifier(n_neighbors=13)
knn.fit(X_train, y_train)
print('k=9 Test Acc: %.3f' % knn.score(X_test, y_test))
# Out:
# k=9 Test Acc: 0.631

# %% [markdown]
# # Test 2: SVC

# %%
from sklearn.svm import SVC
# Create a support vector machine linear classifer and fit it to the training data
model = SVC(kernel='poly')
model.fit(X_train, y_train)
# Out:
# SVC(kernel='poly')

# %%
# Print the model score using the test data
model.score(X_test, y_test)
# Out:
# 0.6189931350114416

# %%
# Calculate the classification report
from sklearn.metrics import classification_report
preds = model.predict(X_test)
print(classification_report(y_test, preds))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.51      0.15      0.23       411
#      CONFIRMED       0.53      0.63      0.57       484
# FALSE POSITIVE       0.68      0.84      0.75       853
#
#       accuracy                           0.62      1748
#      macro avg       0.57      0.54      0.52      1748
#   weighted avg       0.60      0.62      0.58      1748

# %% [markdown]
# # Create model pipeline

# %%
# Create the SVC Model
from sklearn.svm import SVC 
model_exo = SVC(kernel='linear')
model_exo
# Out:
# SVC(kernel='linear')

# %%
# Create the SVC Model
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC 
from sklearn import set_config
set_config(display="diagram")

pipe = make_pipeline(model_exo)
pipe
# Out:
# Pipeline(steps=[('svc', SVC(kernel='linear'))])

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'svc__C': [1, 5, 10, 50],
              'svc__gamma': [0.0001, 0.0005, 0.001, 0.005],
              'svc__kernel': ['linear', 'poly', 'rbf', 'sigmoid']}
grid = GridSearchCV(pipe, param_grid, verbose=3)

# %%
# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=linear .................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=linear, score=0.615, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=linear .................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=linear, score=0.607, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=linear .................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.8s remaining:    0.0s
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=linear, score=0.599, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=linear .................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=linear, score=0.610, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=linear .................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=linear, score=0.629, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=poly ...................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=poly ...................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=poly ...................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=poly ...................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=poly ...................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=rbf ....................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=rbf, score=0.505, total=   0.6s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=rbf ....................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=rbf, score=0.506, total=   0.6s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=rbf ....................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=rbf, score=0.505, total=   0.6s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=rbf ....................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=rbf, score=0.506, total=   0.6s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=rbf ....................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=rbf, score=0.506, total=   0.6s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=sigmoid ................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=sigmoid ................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=sigmoid ................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=sigmoid ................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.0001, svc__kernel=sigmoid ................
# [CV]  svc__C=1, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=linear .................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=linear, score=0.615, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=linear .................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=linear, score=0.607, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=linear .................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=linear, score=0.599, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=linear .................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=linear, score=0.610, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=linear .................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=linear, score=0.629, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=poly ...................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=poly ...................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=poly ...................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=poly ...................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=poly ...................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=rbf ....................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=rbf, score=0.505, total=   0.6s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=rbf ....................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=rbf, score=0.506, total=   0.6s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=rbf ....................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=rbf, score=0.505, total=   0.6s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=rbf ....................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=rbf, score=0.506, total=   0.7s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=rbf ....................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=rbf, score=0.506, total=   0.6s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=sigmoid ................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=sigmoid ................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=sigmoid ................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=sigmoid ................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.0005, svc__kernel=sigmoid ................
# [CV]  svc__C=1, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=linear ..................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=linear, score=0.615, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=linear ..................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=linear, score=0.607, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=linear ..................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=linear, score=0.599, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=linear ..................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=linear, score=0.610, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=linear ..................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=linear, score=0.629, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=poly ....................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=poly ....................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=poly ....................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=poly ....................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=poly, score=0.506, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=poly ....................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=rbf .....................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=rbf, score=0.505, total=   0.6s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=rbf .....................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=rbf, score=0.506, total=   0.7s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=rbf .....................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=rbf, score=0.505, total=   0.6s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=rbf .....................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=rbf, score=0.506, total=   0.6s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=rbf .....................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=rbf, score=0.506, total=   0.7s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=sigmoid .................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=sigmoid .................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=sigmoid .................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=sigmoid .................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.001, svc__kernel=sigmoid .................
# [CV]  svc__C=1, svc__gamma=0.001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=linear ..................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=linear, score=0.615, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=linear ..................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=linear, score=0.607, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=linear ..................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=linear, score=0.599, total=   0.3s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=linear ..................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=linear, score=0.610, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=linear ..................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=linear, score=0.629, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=poly ....................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=poly, score=0.505, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=poly ....................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=poly ....................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=poly ....................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=poly ....................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=rbf .....................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=rbf, score=0.505, total=   0.7s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=rbf .....................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=rbf, score=0.504, total=   0.7s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=rbf .....................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=rbf, score=0.506, total=   0.6s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=rbf .....................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=rbf, score=0.505, total=   0.7s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=rbf .....................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=rbf, score=0.505, total=   0.7s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=sigmoid .................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=sigmoid .................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=sigmoid .................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=sigmoid .................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=sigmoid, score=0.506, total=   0.6s
# [CV] svc__C=1, svc__gamma=0.005, svc__kernel=sigmoid .................
# [CV]  svc__C=1, svc__gamma=0.005, svc__kernel=sigmoid, score=0.506, total=   0.8s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=linear .................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=linear, score=0.636, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=linear .................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=linear, score=0.649, total=   0.7s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=linear .................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=linear, score=0.612, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=linear .................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=linear, score=0.635, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=linear .................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=linear, score=0.651, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=poly ...................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=poly, score=0.505, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=poly ...................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=poly, score=0.506, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=poly ...................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=poly, score=0.505, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=poly ...................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=poly, score=0.506, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=poly ...................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=poly, score=0.506, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=rbf ....................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=rbf, score=0.505, total=   0.9s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=rbf ....................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=rbf, score=0.506, total=   0.7s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=rbf ....................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=rbf, score=0.505, total=   0.7s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=rbf ....................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=rbf, score=0.506, total=   0.7s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=rbf ....................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=rbf, score=0.506, total=   0.6s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=sigmoid ................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=sigmoid ................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=sigmoid ................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=sigmoid ................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.0001, svc__kernel=sigmoid ................
# [CV]  svc__C=5, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=linear .................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=linear, score=0.636, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=linear .................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=linear, score=0.649, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=linear .................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=linear, score=0.612, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=linear .................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=linear, score=0.635, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=linear .................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=linear, score=0.651, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=poly ...................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=poly ...................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=poly ...................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=poly ...................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=poly ...................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=rbf ....................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=rbf, score=0.505, total=   0.7s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=rbf ....................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=rbf, score=0.506, total=   0.7s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=rbf ....................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=rbf, score=0.505, total=   0.7s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=rbf ....................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=rbf, score=0.506, total=   0.7s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=rbf ....................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=rbf, score=0.506, total=   0.7s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=sigmoid ................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=sigmoid ................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=sigmoid ................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=sigmoid ................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.0005, svc__kernel=sigmoid ................
# [CV]  svc__C=5, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=linear ..................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=linear, score=0.636, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=linear ..................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=linear, score=0.649, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=linear ..................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=linear, score=0.612, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=linear ..................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=linear, score=0.635, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=linear ..................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=linear, score=0.651, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=poly ....................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=poly ....................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=poly ....................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=poly ....................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=poly ....................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=rbf .....................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=rbf, score=0.505, total=   0.6s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=rbf .....................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=rbf, score=0.504, total=   0.7s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=rbf .....................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=rbf, score=0.506, total=   0.6s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=rbf .....................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=rbf, score=0.505, total=   0.6s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=rbf .....................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=rbf, score=0.505, total=   0.6s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=sigmoid .................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=sigmoid .................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=sigmoid .................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=sigmoid .................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.001, svc__kernel=sigmoid .................
# [CV]  svc__C=5, svc__gamma=0.001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=linear ..................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=linear, score=0.636, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=linear ..................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=linear, score=0.649, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=linear ..................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=linear, score=0.612, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=linear ..................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=linear, score=0.635, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=linear ..................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=linear, score=0.651, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=poly ....................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=poly ....................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=poly ....................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=poly ....................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=poly ....................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=rbf .....................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=rbf, score=0.537, total=   0.6s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=rbf .....................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=rbf, score=0.523, total=   0.6s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=rbf .....................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=rbf, score=0.523, total=   0.6s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=rbf .....................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=rbf, score=0.525, total=   0.6s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=rbf .....................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=rbf, score=0.533, total=   0.6s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=sigmoid .................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=sigmoid, score=0.519, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=sigmoid .................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=sigmoid, score=0.520, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=sigmoid .................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=sigmoid, score=0.520, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=sigmoid .................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=sigmoid, score=0.520, total=   0.5s
# [CV] svc__C=5, svc__gamma=0.005, svc__kernel=sigmoid .................
# [CV]  svc__C=5, svc__gamma=0.005, svc__kernel=sigmoid, score=0.523, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=linear ................
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=linear, score=0.645, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=linear ................
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=linear, score=0.665, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=linear ................
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=linear, score=0.629, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=linear ................
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=linear, score=0.642, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=linear ................
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=linear, score=0.660, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=poly ..................
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=poly ..................
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=poly ..................
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=poly ..................
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=poly ..................
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=rbf ...................
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=rbf, score=0.505, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=rbf ...................
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=rbf, score=0.506, total=   0.7s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=rbf ...................
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=rbf, score=0.505, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=rbf ...................
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=rbf, score=0.506, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=rbf ...................
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=rbf, score=0.506, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=sigmoid ...............
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=sigmoid ...............
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=sigmoid ...............
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=sigmoid ...............
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.0001, svc__kernel=sigmoid ...............
# [CV]  svc__C=10, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=linear ................
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=linear, score=0.645, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=linear ................
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=linear, score=0.665, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=linear ................
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=linear, score=0.629, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=linear ................
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=linear, score=0.642, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=linear ................
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=linear, score=0.660, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=poly ..................
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=poly ..................
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=poly ..................
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=poly ..................
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=poly ..................
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=rbf ...................
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=rbf, score=0.505, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=rbf ...................
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=rbf, score=0.504, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=rbf ...................
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=rbf, score=0.506, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=rbf ...................
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=rbf, score=0.505, total=   0.7s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=rbf ...................
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=rbf, score=0.505, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=sigmoid ...............
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=sigmoid ...............
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=sigmoid ...............
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=sigmoid ...............
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.0005, svc__kernel=sigmoid ...............
# [CV]  svc__C=10, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=linear .................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=linear, score=0.645, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=linear .................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=linear, score=0.665, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=linear .................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=linear, score=0.629, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=linear .................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=linear, score=0.642, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=linear .................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=linear, score=0.660, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=poly ...................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=poly ...................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=poly ...................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=poly ...................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=poly ...................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=rbf ....................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=rbf, score=0.512, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=rbf ....................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=rbf, score=0.507, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=rbf ....................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=rbf, score=0.512, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=rbf ....................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=rbf, score=0.513, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=rbf ....................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=rbf, score=0.510, total=   0.7s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=sigmoid ................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=sigmoid ................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=sigmoid, score=0.504, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=sigmoid ................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=sigmoid ................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.001, svc__kernel=sigmoid ................
# [CV]  svc__C=10, svc__gamma=0.001, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=linear .................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=linear, score=0.645, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=linear .................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=linear, score=0.665, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=linear .................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=linear, score=0.629, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=linear .................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=linear, score=0.642, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=linear .................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=linear, score=0.660, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=poly ...................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=poly ...................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=poly ...................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=poly ...................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=poly ...................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=rbf ....................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=rbf, score=0.568, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=rbf ....................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=rbf, score=0.549, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=rbf ....................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=rbf, score=0.556, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=rbf ....................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=rbf, score=0.545, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=rbf ....................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=rbf, score=0.562, total=   0.6s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=sigmoid ................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=sigmoid, score=0.537, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=sigmoid ................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=sigmoid, score=0.523, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=sigmoid ................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=sigmoid, score=0.523, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=sigmoid ................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=sigmoid, score=0.525, total=   0.5s
# [CV] svc__C=10, svc__gamma=0.005, svc__kernel=sigmoid ................
# [CV]  svc__C=10, svc__gamma=0.005, svc__kernel=sigmoid, score=0.533, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=linear ................
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=linear, score=0.662, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=linear ................
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=linear, score=0.693, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=linear ................
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=linear, score=0.648, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=linear ................
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=linear, score=0.654, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=linear ................
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=linear, score=0.685, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=poly ..................
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=poly ..................
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=poly ..................
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=poly ..................
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=poly ..................
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=rbf ...................
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=rbf, score=0.505, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=rbf ...................
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=rbf, score=0.504, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=rbf ...................
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=rbf, score=0.506, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=rbf ...................
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=rbf, score=0.505, total=   0.7s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=rbf ...................
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=rbf, score=0.505, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=sigmoid ...............
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=sigmoid ...............
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=sigmoid ...............
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.505, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=sigmoid ...............
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0001, svc__kernel=sigmoid ...............
# [CV]  svc__C=50, svc__gamma=0.0001, svc__kernel=sigmoid, score=0.506, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=linear ................
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=linear, score=0.662, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=linear ................
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=linear, score=0.693, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=linear ................
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=linear, score=0.648, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=linear ................
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=linear, score=0.654, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=linear ................
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=linear, score=0.685, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=poly ..................
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=poly ..................
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=poly ..................
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=poly ..................
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=poly ..................
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=rbf ...................
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=rbf, score=0.537, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=rbf ...................
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=rbf, score=0.523, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=rbf ...................
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=rbf, score=0.523, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=rbf ...................
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=rbf, score=0.525, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=rbf ...................
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=rbf, score=0.533, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=sigmoid ...............
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.519, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=sigmoid ...............
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.520, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=sigmoid ...............
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.520, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=sigmoid ...............
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.520, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.0005, svc__kernel=sigmoid ...............
# [CV]  svc__C=50, svc__gamma=0.0005, svc__kernel=sigmoid, score=0.523, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=linear .................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=linear, score=0.662, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=linear .................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=linear, score=0.693, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=linear .................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=linear, score=0.648, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=linear .................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=linear, score=0.654, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=linear .................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=linear, score=0.685, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=poly ...................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=poly ...................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=poly ...................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=poly ...................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=poly, score=0.506, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=poly ...................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=poly, score=0.506, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=rbf ....................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=rbf, score=0.568, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=rbf ....................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=rbf, score=0.549, total=   0.7s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=rbf ....................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=rbf, score=0.556, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=rbf ....................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=rbf, score=0.546, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=rbf ....................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=rbf, score=0.562, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=sigmoid ................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=sigmoid, score=0.537, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=sigmoid ................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=sigmoid, score=0.523, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=sigmoid ................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=sigmoid, score=0.523, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=sigmoid ................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=sigmoid, score=0.525, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.001, svc__kernel=sigmoid ................
# [CV]  svc__C=50, svc__gamma=0.001, svc__kernel=sigmoid, score=0.533, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=linear .................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=linear, score=0.662, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=linear .................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=linear, score=0.693, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=linear .................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=linear, score=0.648, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=linear .................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=linear, score=0.654, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=linear .................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=linear, score=0.685, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=poly ...................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=poly ...................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=poly ...................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=poly, score=0.505, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=poly ...................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=poly ...................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=poly, score=0.506, total=   0.4s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=rbf ....................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=rbf, score=0.590, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=rbf ....................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=rbf, score=0.589, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=rbf ....................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=rbf, score=0.577, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=rbf ....................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=rbf, score=0.573, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=rbf ....................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=rbf, score=0.594, total=   0.6s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=sigmoid ................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=sigmoid, score=0.579, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=sigmoid ................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=sigmoid, score=0.569, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=sigmoid ................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=sigmoid, score=0.567, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=sigmoid ................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=sigmoid, score=0.565, total=   0.5s
# [CV] svc__C=50, svc__gamma=0.005, svc__kernel=sigmoid ................
# [CV]  svc__C=50, svc__gamma=0.005, svc__kernel=sigmoid, score=0.572, total=   0.5s
# [Parallel(n_jobs=1)]: Done 320 out of 320 | elapsed:  2.7min finished
# GridSearchCV(estimator=Pipeline(steps=[('svc', SVC(kernel='linear'))]),
#              param_grid={'svc__C': [1, 5, 10, 50],
#                          'svc__gamma': [0.0001, 0.0005, 0.001, 0.005],
#                          'svc__kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              verbose=3)

# %%
# List the best parameters for this dataset
print(f"Best params: {grid.best_params_}")
# List the best score
print(f"Best score: {grid.best_score_}")
# Out:
# Best params: {'svc__C': 50, 'svc__gamma': 0.0001, 'svc__kernel': 'linear'}
# Best score: 0.6683200649109657

# %%
grid.best_estimator_
# Out:
# Pipeline(steps=[('svc', SVC(C=50, gamma=0.0001, kernel='linear'))])

# %%
# Make predictions with the hypertuned model
predictions = grid.predict(X_test)

# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions, target_names = ["CANDIDATE", "CONFIRMED", "FALSE POSITIVE"]))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.42      0.36      0.39       411
#      CONFIRMED       0.58      0.64      0.61       484
# FALSE POSITIVE       0.77      0.78      0.78       853
#
#       accuracy                           0.64      1748
#      macro avg       0.59      0.59      0.59      1748
#   weighted avg       0.64      0.64      0.64      1748

# %% [markdown]
# # Save the Model

# %%
# save model using joblib
import joblib
filename = '../Model/travis_tyler.sav'
joblib.dump(grid.best_estimator_, filename)
# Out:
# ['../Model/travis_tyler.sav']
